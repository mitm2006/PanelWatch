# %%
import torch
import os
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
from collections import Counter
import numpy as np
from torch.utils.data import random_split
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import WeightedRandomSampler
from copy import deepcopy
from PIL import Image
import torch.nn.functional as F
from torchmetrics.classification import MulticlassConfusionMatrix

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
])

# %%
dataset = datasets.ImageFolder(
    root='Data/Faulty_solar_panel',
    transform=transform
)

print(dataset.classes)
# Out:
# ['Bird-drop', 'Clean', 'Dusty', 'Electrical-damage', 'Physical-Damage', 'Snow-Covered']

# %%
dataloader = DataLoader(dataset, batch_size=32, shuffle=True)

# %%
labels = [label for _, label in dataset]
count = Counter(labels)

for i, cls in enumerate(dataset.classes):
    print(f"{cls}: {count[i]}")
# Out:
# Bird-drop: 207
# Clean: 193
# Dusty: 190
# Electrical-damage: 103
# Physical-Damage: 69
# Snow-Covered: 123

# %%
images, labels = next(iter(dataloader))

plt.figure(figsize=(10,6))
for i in range(6):
    plt.subplot(2,3,i+1)
    img = images[i].permute(1,2,0)  
    plt.imshow(img)
    plt.title(dataset.classes[labels[i]])
    plt.axis('off')

plt.tight_layout()

# %%
img, label = dataset[0]
print(img.shape)
# Out:
# torch.Size([3, 224, 224])

# %%
img = images[0].numpy()
plt.hist(img.ravel(), bins=50)
plt.title("Pixel Distribution")
# Out:
# Text(0.5, 1.0, 'Pixel Distribution')

# %%
train_size = int(0.9*len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# %%
len(train_dataset), len(val_dataset)
# Out:
# (796, 89)

# %%
train_dataset.dataset.transform = transforms.Compose([
    transforms.Resize((224,224)),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.3, saturation=0.25, hue=0.1),
    transforms.ToTensor()
])

# %%
images, labels = next(iter(DataLoader(train_dataset, batch_size=32, shuffle=True)))

plt.figure(figsize=(10,6))
for i in range(6):
    plt.subplot(2,3,i+1)
    img = images[i].permute(1,2,0)  
    plt.imshow(img)
    plt.title(dataset.classes[labels[i]])
    plt.axis('off')

plt.tight_layout()

# %%
counts = torch.tensor([184, 173, 171, 95, 63, 110], dtype=torch.float)
weights = 1.0 / counts
weights = (weights / weights.sum() * len(counts)).to(device)

print(weights)
# Out:
# tensor([0.6205, 0.6599, 0.6677, 1.2018, 1.8122, 1.0379], device='cuda:0')

# %%
#Hyperparameters
Leaky_ReLU_negative_slope = 0.01
in_channel=3
out_channel = 64

Dropout_rate = 0.18
lr=0.001 #0.0005
lr_patience = 2
lr_factor = 0.5
num_epochs = 50
weights_decay = 1e-5

batch_size = 16
patience = 8

kernel_size = 3
stride = 2
padding_count = 1

# %%
class ConditionClassification(nn.Module):
    def __init__(self, in_channel, out_channel, output_size):
        super().__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(in_channel, out_channel, kernel_size=kernel_size, stride=stride, padding=padding_count),
            nn.BatchNorm2d(out_channel),
            nn.LeakyReLU(negative_slope=Leaky_ReLU_negative_slope),
            nn.MaxPool2d(2),


            nn.Conv2d(out_channel, out_channel*2, kernel_size=kernel_size, stride=stride, padding=padding_count),
            nn.BatchNorm2d(out_channel*2),
            nn.LeakyReLU(negative_slope=Leaky_ReLU_negative_slope),
            nn.MaxPool2d(2),
            

            nn.Conv2d(out_channel*2, out_channel*4, kernel_size=kernel_size, stride=stride, padding=padding_count),
            nn.BatchNorm2d(out_channel*4),
            nn.LeakyReLU(negative_slope=Leaky_ReLU_negative_slope),
            nn.Dropout2d(Dropout_rate), 
            nn.MaxPool2d(2),

            nn.Conv2d(out_channel*4, out_channel*8, kernel_size=kernel_size, stride=stride, padding=padding_count),
            nn.BatchNorm2d(out_channel*8),
            nn.LeakyReLU(negative_slope=Leaky_ReLU_negative_slope),
            nn.Dropout2d(Dropout_rate), 
        )

        self.fc = nn.Sequential(
            nn.Linear(out_channel*32,512),
            nn.BatchNorm1d(512),
            nn.LeakyReLU(negative_slope=Leaky_ReLU_negative_slope),
            nn.Dropout(Dropout_rate),
            nn.Linear(512, output_size)
        )

    def forward(self, x):
        x = self.conv(x)  
        x = torch.flatten(x, 1)  
        x = self.fc(x)       
        return x

# %%
model = ConditionClassification(in_channel=in_channel, out_channel=out_channel, output_size=len(dataset.classes))
model=model.to(device)
critertion = nn.CrossEntropyLoss(weight=weights.to(device))
optimizer = optim.Adam(model.parameters(), lr=lr, weight_decay= weights_decay)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer=optimizer, mode='min', factor=lr_factor, patience=lr_patience)

# %%
epoch_losses = []
accuracies = []
val_losses = []
best_val_loss = float("inf")
best_model_state = None
best_model_accuracy = 0.0
counter = 0
min_delta = 1e-4
train_load = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_load = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
for epoch in range(num_epochs):
#Training 
    model.train()
    running_loss = 0.0
    for images, labels in train_load:
        images = images.to(device)
        labels = labels.to(device)
        output = model(images)
        loss = critertion(output, labels)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * images.size(0)        
    train_loss = running_loss / len(train_dataset)
    epoch_losses.append(train_loss)

# validation
    model.eval()
    correct = 0
    total = 0
    val_loss=0.0
    with torch.no_grad():
        for images, labels in val_load:
            images = images.to(device)
            labels = labels.to(device)

            output = model(images)

            _, predicted = torch.max(output, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

            loss = critertion(output, labels)
            val_loss += loss.item()*images.size(0)

    accuracy = 100 * correct / total
    val_loss/=len(val_dataset)
    scheduler.step(val_loss)
    val_losses.append(val_loss)
    accuracies.append(accuracy)
    print(f"Epoch {epoch+1}: Train Loss={train_loss:.4f}, Val Loss={val_loss:.4f}, Acc={accuracy:.2f}%")

    if accuracy > best_model_accuracy:
        best_model_accuracy = accuracy
        best_model_state = deepcopy(model.state_dict())

    if val_loss < best_val_loss-min_delta:
        best_val_loss = val_loss
        counter = 0
    else:
        counter +=1
    if counter >= patience:
        print("Early stopping triggered")
        break
# Out:
# Epoch 1: Train Loss=1.5958, Val Loss=1.5813, Acc=41.57%
# Epoch 2: Train Loss=1.3343, Val Loss=1.4701, Acc=49.44%
# Epoch 3: Train Loss=1.2242, Val Loss=1.4229, Acc=59.55%
# Epoch 4: Train Loss=1.1884, Val Loss=1.3395, Acc=52.81%
# Epoch 5: Train Loss=1.0821, Val Loss=1.3851, Acc=58.43%
# Epoch 6: Train Loss=1.0198, Val Loss=1.3787, Acc=52.81%
# Epoch 7: Train Loss=0.9182, Val Loss=2.6383, Acc=50.56%
# Epoch 8: Train Loss=0.8726, Val Loss=1.3493, Acc=58.43%
# Epoch 9: Train Loss=0.7397, Val Loss=1.2196, Acc=60.67%
# Epoch 10: Train Loss=0.8032, Val Loss=1.2862, Acc=64.04%
# Epoch 11: Train Loss=0.7589, Val Loss=1.0809, Acc=61.80%
# Epoch 12: Train Loss=0.7025, Val Loss=1.1199, Acc=68.54%
# Epoch 13: Train Loss=0.7122, Val Loss=1.1517, Acc=71.91%
# Epoch 14: Train Loss=0.6490, Val Loss=0.9169, Acc=67.42%
# Epoch 15: Train Loss=0.6295, Val Loss=0.9330, Acc=65.17%
# Epoch 16: Train Loss=0.6189, Val Loss=1.2666, Acc=64.04%
# Epoch 17: Train Loss=0.5684, Val Loss=1.0790, Acc=68.54%
# Epoch 18: Train Loss=0.5424, Val Loss=0.9047, Acc=70.79%
# Epoch 19: Train Loss=0.4321, Val Loss=0.9549, Acc=76.40%
# Epoch 20: Train Loss=0.4230, Val Loss=0.9399, Acc=70.79%
# Epoch 21: Train Loss=0.4260, Val Loss=0.8767, Acc=74.16%
# Epoch 22: Train Loss=0.4072, Val Loss=1.0114, Acc=70.79%
# Epoch 23: Train Loss=0.4110, Val Loss=1.1524, Acc=70.79%
# Epoch 24: Train Loss=0.4152, Val Loss=0.9583, Acc=74.16%
# Epoch 25: Train Loss=0.3706, Val Loss=0.9887, Acc=76.40%
# Epoch 26: Train Loss=0.3288, Val Loss=0.9902, Acc=76.40%
# Epoch 27: Train Loss=0.3277, Val Loss=0.8231, Acc=78.65%
# Epoch 28: Train Loss=0.3241, Val Loss=0.8589, Acc=79.78%
# Epoch 29: Train Loss=0.3319, Val Loss=1.1015, Acc=75.28%
# Epoch 30: Train Loss=0.3121, Val Loss=0.9620, Acc=80.90%
# Epoch 31: Train Loss=0.3282, Val Loss=0.9477, Acc=77.53%
# Epoch 32: Train Loss=0.2744, Val Loss=1.0874, Acc=73.03%
# Epoch 33: Train Loss=0.2976, Val Loss=0.8391, Acc=75.28%
# Epoch 34: Train Loss=0.2820, Val Loss=0.8325, Acc=77.53%
# Epoch 35: Train Loss=0.2427, Val Loss=0.8136, Acc=82.02%
# Epoch 36: Train Loss=0.2602, Val Loss=0.9150, Acc=78.65%
# Epoch 37: Train Loss=0.2624, Val Loss=0.9171, Acc=78.65%
# Epoch 38: Train Loss=0.2824, Val Loss=1.0280, Acc=70.79%
# Epoch 39: Train Loss=0.2201, Val Loss=0.9232, Acc=78.65%
# Epoch 40: Train Loss=0.2346, Val Loss=0.8832, Acc=79.78%
# Epoch 41: Train Loss=0.2246, Val Loss=0.9265, Acc=73.03%
# Epoch 42: Train Loss=0.2269, Val Loss=0.9957, Acc=73.03%
# Epoch 43: Train Loss=0.2214, Val Loss=0.9053, Acc=76.40%
# Early stopping triggered

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(range(1, len(epoch_losses) + 1), epoch_losses, marker='o')
plt.plot(range(1, len(val_losses) + 1), val_losses, marker='s')
plt.title("Tracking Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.subplot(1,2,2)
plt.plot(range(1, len(accuracies) + 1), accuracies, marker='o')
plt.title("Tracking Training Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy (%)")
plt.tight_layout()
plt.show()

# %%
##model.load_state_dict(best_model_state)
state_dict = torch.load("Models/High_Accuracy_Model.pth", map_location=device)
model.load_state_dict(state_dict)
model = model.to(device)
metric = MulticlassConfusionMatrix(num_classes=6).to(device)
with torch.no_grad():
    model.eval()
    correct = 0
    total = 0
    for images, labels in DataLoader(val_dataset, batch_size=16):
        images = images.to(device)
        labels = labels.to(device)
        output = model(images)
        _, predicted = torch.max(output.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()
        metric.update(predicted, labels)
print(f"Accuracy: {100 * correct / total:.2f}%")
confmat = metric.compute()
print(confmat)
# Out:
# Accuracy: 93.26%
# tensor([[22,  0,  1,  0,  0,  0],
#         [ 1, 19,  0,  0,  0,  0],
#         [ 1,  1, 19,  0,  1,  0],
#         [ 0,  0,  0,  7,  1,  0],
#         [ 0,  0,  0,  0,  5,  0],
#         [ 0,  0,  0,  0,  0, 11]], device='cuda:0')

# %%
print(torch.unique(predicted, return_counts=True))
print(torch.unique(labels, return_counts=True))
print("Pred:", predicted[:10])
print("True:", labels[:10])
# Out:
# (tensor([0, 1, 2, 3, 4, 5], device='cuda:0'), tensor([1, 2, 2, 1, 1, 2], device='cuda:0'))
# (tensor([0, 1, 2, 3, 5], device='cuda:0'), tensor([2, 3, 2, 1, 1], device='cuda:0'))
# Pred: tensor([2, 5, 1, 0, 5, 4, 1, 2, 3], device='cuda:0')
# True: tensor([2, 1, 0, 0, 5, 1, 1, 2, 3], device='cuda:0')

# %%
test_images = "Data\Test-data"
image_paths = [os.path.join(test_images, img) for img in os.listdir(test_images) if img.endswith((".jpg", ".png"))]

# %%
class_names = ["Bird-Drop", "Clean", "Dusty", "Electrical-damage", "Physical-damage", "Snow-Covered"] 

model.eval()

for img_path in image_paths:
    image = Image.open(img_path).convert("RGB")
    
    input_tensor = transform(image)
    input_tensor = input_tensor.unsqueeze(0).to(device) 

    with torch.no_grad():
        outputs = model(input_tensor)
        _, predicted = torch.max(outputs, 1)

    predicted_class = class_names[predicted.item()]
    
    print(f"{img_path} --> {predicted_class}")
# Out:
# Data\Test-data\Bird_Drop.png --> Bird-Drop
# Data\Test-data\Clean.jpg --> Clean
# Data\Test-data\Dusty.png --> Bird-Drop
# Data\Test-data\Dusty_1.png --> Dusty
# Data\Test-data\Electical_damage.png --> Electrical-damage
# Data\Test-data\Electrical_damage.png --> Electrical-damage
# Data\Test-data\Physical_damage.png --> Physical-damage
# Data\Test-data\Snow_covered.png --> Snow-Covered

# %%
torch.save(model.state_dict(), "Models/High_Accuracy_Model.pth")
